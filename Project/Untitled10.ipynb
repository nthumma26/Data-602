# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv('Current_Tax_Sale_list.csv')

# %%
data.head()
# Out:
#               X              Y            address ownership land_use_c  \
# 0  1.412623e+06  595748.818596  1143 N FULTON AVE         H          R
# 1  1.412695e+06  595473.921836     1720 RIGGS AVE         H          R
# 2  1.412747e+06  595476.478590     1712 RIGGS AVE         N          R
# 3  1.412760e+06  595477.113759     1710 RIGGS AVE         N          R
# 4  1.412999e+06  596122.780447    1625 LAURENS ST         N          R
#
#    total_lien  total_li_1           neighborho        when_sold    being_remo  \
# 0     1613.71        0.00  SANDTOWN-WINCHESTER  SOLD IN 4 YEARS  WILL BE SOLD
# 1    29687.35    28612.05  SANDTOWN-WINCHESTER  SOLD IN 4 YEARS  WILL BE SOLD
# 2    22180.70    22070.48  SANDTOWN-WINCHESTER  SOLD IN 4 YEARS  WILL BE SOLD
# 3    88346.63    88236.41  SANDTOWN-WINCHESTER  SOLD IN 4 YEARS  WILL BE SOLD
# 4      335.20       30.00  SANDTOWN-WINCHESTER       NEVER SOLD  WILL BE SOLD
#
# ...

# %%
data.isnull().sum()
# Out:
# X              24
# Y              24
# address       696
# ownership       0
# land_use_c      0
# total_lien      0
# total_li_1      0
# neighborho      0
# when_sold       0
# being_remo      0
# block           0
# lot             0
# pin             0
# soldto          0
# ownername       0
# tax_base        0
# city_tax        0
# state_tax       0
# total_tax       0
# total_3yea      0
# years_elig      0
# deed_date     417
# council_di      0
# objectid        0
# dtype: int64

# %%
data.dtypes
# Out:
# X             float64
# Y             float64
# address        object
# ownership      object
# land_use_c     object
# total_lien    float64
# total_li_1    float64
# neighborho     object
# when_sold      object
# being_remo     object
# block          object
# lot            object
# pin            object
# soldto         object
# ownername      object
# tax_base        int64
# city_tax      float64
# state_tax     float64
# total_tax     float64
# total_3yea    float64
# years_elig      int64
# deed_date      object
# council_di      int64
# objectid        int64
# dtype: object

# %%
#Distribution of total_tax
plt.figure(figsize=(10,5))
(sns.distplot(data['total_tax'],bins=50,kde=True,color = "green")).set(xlabel="Sales Tax", ylabel = "Count", title='Distribution of Sales Tax')
plt.show()
# Out:
# C:\Users\nthum\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data.describe()
# Out:
#                   X              Y    total_lien    total_li_1      tax_base  \
# count  1.154600e+04   11546.000000  1.157000e+04  1.157000e+04  1.157000e+04
# mean   1.417335e+06  596911.736952  3.702790e+04  3.536629e+04  1.129286e+05
# std    1.127749e+04    9266.271701  9.112115e+04  9.098396e+04  8.843382e+05
# min    1.394040e+06  560818.302828  2.542300e+02  0.000000e+00  0.000000e+00
# 25%    1.408874e+06  590915.450310  1.054140e+03  2.581000e+01  7.000000e+03
# 50%    1.414410e+06  596774.290791  2.611130e+03  5.866900e+02  2.818350e+04
# 75%    1.427130e+06  601581.473106  2.130543e+04  1.898682e+04  8.823300e+04
# max    1.445413e+06  621232.026488  1.570473e+06  1.559891e+06  3.927680e+07
#
#             city_tax     state_tax      total_tax     total_3yea  \
# count   11570.000000  11570.000000   11570.000000   11570.000000
# mean     1846.291077     91.985916    1938.276993    1661.615822
# std      5929.764357    295.433132    6225.197489    4899.053177
# ...

# %%
#comparing the propert type by its total_tax
plt.figure(figsize=(10,4))
sns.barplot(data['ownership'],data['total_tax'])
# Out:
# C:\Users\nthum\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ownership', ylabel='total_tax'>

# %%
#visualization of correlation matrix
corrmat = data.corr()
f, ax = plt.subplots(figsize=(8, 8))
sns.heatmap(corrmat, vmax=.8, square=True);
